# %%
# upload dataset
# Group1: https://www.kaggle.com/datasets/mohithsairamreddy/salary-data
# Group2: https://www.kaggle.com/datasets/jaderz/hospital-beds-management?select=services_weekly.csv
# Group3: https://www.kaggle.com/datasets/hmavrodiev/london-bike-sharing-dataset
# Group4: https://www.kaggle.com/datasets/jocelyndumlao/inclusive-economics-growth-determinants
# Group5: https://www.kaggle.com/datasets/kbrakssa/students-grading-dataset


import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df= pd.read_csv("Salary_Data.csv")
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
# Exercise 1
# Group1: Test whether there is a significant difference in the average salary between two groups (e.g., Group A and Group B).
# T-statistic: 10.486078
# P-value:1.578530e-25
# There is a significant difference in average salary.
# Group2: Testing Whether Events (like"flu") Significantly Impact Staff Morale
# Group3: weekend has an effect on the number of electric cycles rented (cnt)
# Group4: Test whether there is a significant difference in the grdp_capita of province A(ACEH) and province B(BALI)
# Group5: Does High Stress Lead to Lower Performance?
# Identify H_o and H_1
# Out:
# T-statistic: 10.486078
# P-value:1.578530e-25
# There is a significant difference in average salary.

# %%
# Exercise 2
# Data cleanig 
# print(df.head())
# print(df.isnull().sum())
df["Years of Experience"].dropna()
df["Education Level"].dropna()
df_cleaned = df.dropna(subset=["Salary", "Gender"])

# Q1 = df["Years of Experience"].quantile(0.25)
# Q3 = df["Years of Experience"].quantile(0.75)
# IQR = Q3 - Q1
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
# print("Lower bound:", lower_bound)
# print("Upper bound:", upper_bound)
# outliers = df[(df["Years of Experience"] < lower_bound) | (df["Years of Experience"] > upper_bound)]
# print("Outliers in Years of Experience:")
# print(outliers.count(),df.notnull().count())
# Out:
# 0              Bachelor's
# 1                Master's
# 2                     PhD
# 3              Bachelor's
# 4                Master's
# 5              Bachelor's
# 6                Master's
# 7              Bachelor's
# 8              Bachelor's
# 9                     PhD
# 10               Master's
# 11             Bachelor's
# 12             Bachelor's
# 13               Master's
# 14             Bachelor's
# 15             Bachelor's
# 16               Master's
# 17                    PhD
# 18             Bachelor's
# 19             Bachelor's
# 20               Master's
# 21               Master's
# 22             Bachelor's
# 23             Bachelor's
# 24               Master's
# 25             Bachelor's
# 26               Master's
# 27             Bachelor's
# 28                    PhD
# 29               Master's
# 30             Bachelor's
# 31             Bachelor's
# 32               Master's
# 33             Bachelor's
# 34                    PhD
# ...

# %%
# Exercise 3
# EDA for column testing 
# Check basic info and summary statistics for Salary and Gender columns
print(df_cleaned[["Gender", "Salary"]].info())
print(df_cleaned[["Gender", "Salary"]].describe())

# Visualize salary distribution by gender
sns.boxplot(x="Gender", y="Salary", data=df_cleaned)
plt.title("Salary Distribution by Gender")
plt.show()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6699 entries, 0 to 6703
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  6699 non-null   str
#  1   Salary  6699 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 157.0 KB
# None
#               Salary
# count    6699.000000
# mean   115326.964771
# std     52786.183911
# min       350.000000
# 25%     70000.000000
# 50%    115000.000000
# 75%    160000.000000
# max    250000.000000

# %%
# Exercise 4
# Discribtive statistics of testing column (count, mean, std)

print(df_cleaned.groupby("Gender")["Salary"].agg(['count', 'mean', 'std']))
# Out:
#         count           mean           std
# Gender
# Female   3013  107888.998672  52723.610035
# Male     3672  121389.870915  52092.726368
# Other      14  125869.857143  44242.382776

# %%
# Exercise 5
# Calculate T-Statistic and P-Value
# significance level is 0.05
male_salary = df[df["Gender"] == "Male"]["Salary"].dropna()
female_salary = df[df["Gender"] == "Female"]["Salary"].dropna()
t_stat, p_value = ttest_ind(male_salary, female_salary)
print(f"T-statistic: {t_stat:2f}")
print(f"P-value:{p_value:2e}")
if p_value < 0.05:
    print("There is a significant difference in average salary.")
else:
    print("There is no significant difference in average salary.")
# Out:
# T-statistic: 10.486078
# P-value:1.578530e-25
# There is a significant difference in average salary.

# %%
# Exercise 6
# Conclussion result 
# as a result on test  we need to check condition perharp p-value<0.05
# if it true meaning There is a significant difference in average salary. while if it false There is no significant difference in average salary.
